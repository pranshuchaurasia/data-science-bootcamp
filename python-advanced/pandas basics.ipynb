# %%
import pandas as pd

# %%
pd.read_excel(r'C:\Users\Pranshu Chaurasia\Desktop\data-science-bootcamp\sample_datasets\Attribute DataSet.xlsx')
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
pd.read_excel('C:/Users/Pranshu Chaurasia/Desktop/data-science-bootcamp/sample_datasets/Attribute DataSet.xlsx')
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df = pd.read_excel('C:\\Users\\Pranshu Chaurasia\\Desktop\\data-science-bootcamp\\sample_datasets\\Attribute DataSet.xlsx')

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#To read data from multiple sheets
#To give a custom column name use names
# To remove first roaw as column name use header =None
#pd.read_excel('C:/Users/Pranshu Chaurasia/Desktop/data-science-bootcamp/sample_datasets/Attribute DataSet.xlsx',sheet_name='pran',header=None,names=["A","B","C"])

# %%
df.head(2)
# Out:
#      Dress_ID   Style Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852    Sexy   Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089  Casual   Low     0.0    L  Summer   o-neck        Petal
#
#   waiseline    Material FabricType Decoration Pattern Type  Recommendation
# 0    empire         NaN    chiffon    ruffles       animal               1
# 1   natural  microfiber        NaN    ruffles       animal               0

# %%
df.tail()
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 495  713391965  Casual      Low     4.7     M  Spring     o-neck         full
# 496  722565148    Sexy      Low     4.3  free  Summer     o-neck         full
# 497  532874347  Casual  Average     4.7     M  Summer     v-neck         full
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline  Material  FabricType Decoration Pattern Type  Recommendation
# 495   natural  polyster         NaN        NaN        solid               1
# 496    empire    cotton         NaN        NaN          NaN               0
# 497    empire    cotton         NaN       lace        solid               1
# 498    empire      silk  broadcloth   applique        print               1
# 499    empire    cotton    Corduroy       lace        solid               0

# %%
pd.read_csv(r'C:\Users\Pranshu Chaurasia\Desktop\data-science-bootcamp\sample_datasets\haberman.csv',header=None,names=['Age','Year of Operation','No. Of. Positives','Survival status'])
# Out:
#      Age  Year of Operation  No. Of. Positives  Survival status
# 0     30                 64                  1                1
# 1     30                 62                  3                1
# 2     30                 65                  0                1
# 3     31                 59                  2                1
# 4     31                 65                  4                1
# ..   ...                ...                ...              ...
# 301   75                 62                  1                1
# 302   76                 67                  0                1
# 303   77                 65                  3                1
# 304   78                 65                  1                2
# 305   83                 58                  2                2
#
# [306 rows x 4 columns]

# %%
pd.read_csv(r'C:\Users\Pranshu Chaurasia\Desktop\data-science-bootcamp\sample_datasets\haberman1.csv',header=None,sep='@',names=['Age','Year of Operation','No. Of. Positives','Survival status'])
# Out:
#      Age  Year of Operation  No. Of. Positives  Survival status
# 0     30                 64                  1                1
# 1     30                 62                  3                1
# 2     30                 65                  0                1
# 3     31                 59                  2                1
# 4     31                 65                  4                1
# ..   ...                ...                ...              ...
# 301   75                 62                  1                1
# 302   76                 67                  0                1
# 303   77                 65                  3                1
# 304   78                 65                  1                2
# 305   83                 58                  2                2
#
# [306 rows x 4 columns]

# %%
pd.read_csv('https://raw.githubusercontent.com/datasets/covid-19/main/data/worldwide-aggregate.csv')
# Out:
#            Date  Confirmed  Recovered   Deaths  Increase rate
# 0    2020-01-22        557         30       17            NaN
# 1    2020-01-23        657         32       18      17.953321
# 2    2020-01-24        944         39       26      43.683409
# 3    2020-01-25       1437         42       42      52.224576
# 4    2020-01-26       2120         56       56      47.529576
# ..          ...        ...        ...      ...            ...
# 811  2022-04-12  500880363          0  6185040       0.207437
# 812  2022-04-13  501920234          0  6189593       0.207609
# 813  2022-04-14  502892186          0  6193401       0.193647
# 814  2022-04-15  503606396          0  6195647       0.142021
# 815  2022-04-16  504155459          0  6197159       0.109026
#
# [816 rows x 5 columns]

# %%
a= pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
type(a)
# Out:
# list

# %%
a[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
len(a)
# Out:
# 1

# %%
js=pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
js['user'][0]
# Out:
# {'login': 'JasonMendoza2008',
#  'id': 56092290,
#  'node_id': 'MDQ6VXNlcjU2MDkyMjkw',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/56092290?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/JasonMendoza2008',
#  'html_url': 'https://github.com/JasonMendoza2008',
#  'followers_url': 'https://api.github.com/users/JasonMendoza2008/followers',
#  'following_url': 'https://api.github.com/users/JasonMendoza2008/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/JasonMendoza2008/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/JasonMendoza2008/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/JasonMendoza2008/subscriptions',
#  'organizations_url': 'https://api.github.com/users/JasonMendoza2008/orgs',
#  'repos_url': 'https://api.github.com/users/JasonMendoza2008/repos',
#  'events_url': 'https://api.github.com/users/JasonMendoza2008/events{/privacy}',
# ...

# %%
df.to_json('C:\\Users\\Pranshu Chaurasia\\Desktop\\data-science-bootcamp\\sample_datasets\\attributes_dataset.json')

# %%
pwd
# Out:
# 'C:\\Users\\Pranshu Chaurasia\\Desktop\\data-science-bootcamp\\data-science-bootcamp\\python-advanced'
