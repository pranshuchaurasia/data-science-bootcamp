# %%
import cufflinks as cf
import pandas as pd
import numpy as np
import seaborn as sns

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df=pd.DataFrame(np.random.randn(100,3))

# %%
df
# Out:
#            0         1         2
# 0  -0.663673  0.524771 -0.533879
# 1   0.222639  0.964467 -1.043696
# 2   0.152528  0.510093 -0.207369
# 3  -0.628480  0.711390 -1.041375
# 4  -2.053998 -1.170142 -0.988020
# ..       ...       ...       ...
# 95 -0.692360  0.431982 -0.458081
# 96 -0.467730  0.400815  0.256275
# 97 -1.064456 -0.701392  0.077006
# 98 -0.008036  0.168601 -0.044639
# 99  0.365880 -0.549168  1.418338
#
# [100 rows x 3 columns]

# %%
df.iplot()
# Out:
# <div>                            <div id="5ffff2a1-4184-44d3-9ac7-d2667a0bfd62" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2=pd.DataFrame(np.random.randint(3,100,(100,2)))

# %%
df2
# Out:
#      0   1
# 0   28  67
# 1   31   3
# 2   95  96
# 3   82  86
# 4   14  90
# ..  ..  ..
# 95  14  46
# 96  66  81
# 97  60  31
# 98  63  50
# 99  26  74
#
# [100 rows x 2 columns]

# %%
df2.iplot()
# Out:
# <div>                            <div id="07fe43c5-c735-49df-a089-9ce05e1898be" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
